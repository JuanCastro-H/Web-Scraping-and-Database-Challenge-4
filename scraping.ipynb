# %%
# ==================================
# BLOQUE 1: 
# ==================================

print()

# ==================================
#  LIBRERIAS PARA EL SCRAPING
# ==================================

import requests                # Simula un navegador para poder obtener todo su HTML crudo
from bs4 import BeautifulSoup  # Herramienta (clase) que convierte HTML en algo que Python pueda entender y navegar


# ======================================================
#  INICIALIZACIÓN DEL SCRAPER Y VALIDACIÓN DE CONEXIÓN
# ======================================================

url = "https://books.toscrape.com/"  # URL de la pagina pedida.
response = requests.get(url)         # Creamos un objeto de respuesta de la clase requests con el comando .get() pasandole la URL.
response.raise_for_status()

print(f"Estado de la respuesta de la pagina: {response.status_code}")                # 200 = todo salio bien.
print(f" Pedazo del codigo HTML de la pagina:\n {response.text[:500]}\nHasta aca" )  # HTML (solo un pedazo).


# ==================================
#  CREACION DE LA SOPA DE CODIGO
# ==================================
print("--- soup ---")
soup = BeautifulSoup(response.text, "html.parser") # Sopa de Datos.
print(soup)
# Out:
# Estado de la respuesta de la pagina: 200
#  Pedazo del codigo HTML de la pagina:
#  <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->
#     <head>
#         <title>
#     All products | Books to Scrape - Sandbox
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8" /
# Hasta aca
# --- soup ---
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# ...

# %%
# ==================================
# BLOQUE 2: 
# ==================================

# -------------------------------------------------
#  EXTRACCIÓN DE CATEGORÍAS DESDE EL HTML 
# -------------------------------------------------

bloque_categorias = soup.find("ul", class_="nav-list").find("ul") # Busca un <ul> con la clase "nav-list"n para buscar otro <ul> dentro de el;
categorias_html = bloque_categorias.find_all("a")                 # busca todos los <a> dentro del bloque de categorias (links y txt).
# (.find(un solo elemento) .find_all(lista de elementos))

# Nombre-Link
categorias = {}

# -------------------------------------------------
#  SCRAPING DE CATEGORÍAS Y CONSTRUCCIÓN DE URLS
# -------------------------------------------------

for c in categorias_html: 

    nombre = c.text.strip()            # Nombre (limpia) eliminando espacios. 
    href   = c["href"]                 # Accede al atributo href y consigue la Url relativa.
    url_completa = url + href          # Creamos una Url completa.
    categorias[nombre] = url_completa  # Agrega al diccionacio clave=nombre y valor=url_completa.


# -------------------------------------------------
#  VISUALIZACIÓN DE CATEGORÍAS EXTRAÍDAS
# -------------------------------------------------

print("TOTAL Categorias: ", len(categorias))
print("--- # ---")

for nombre, link in categorias.items():   # Desempaqueta la info de categoria.
    print(f"Categoria: {nombre}: {link}") # Imprime el nombre y link de cada categoria.

print()
# Out:
# TOTAL Categorias:  50
# --- # ---
# Categoria: Travel: https://books.toscrape.com/catalogue/category/books/travel_2/index.html
# Categoria: Mystery: https://books.toscrape.com/catalogue/category/books/mystery_3/index.html
# Categoria: Historical Fiction: https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html
# Categoria: Sequential Art: https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html
# Categoria: Classics: https://books.toscrape.com/catalogue/category/books/classics_6/index.html
# Categoria: Philosophy: https://books.toscrape.com/catalogue/category/books/philosophy_7/index.html
# Categoria: Romance: https://books.toscrape.com/catalogue/category/books/romance_8/index.html
# Categoria: Womens Fiction: https://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html
# Categoria: Fiction: https://books.toscrape.com/catalogue/category/books/fiction_10/index.html
# ...

# %%
# ==================================
# BLOQUE 3: 
# ==================================

# Lista Global
books_data = []

# Reconstruccion pro de la URL
from urllib.parse import urljoin

# --- Diccionario Raiting ---
rating_map = {
    "One":   1,
    "Two":   2,
    "Three": 3,
    "Four":  4,
    "Five":  5
}

# -------------------------------------
# Recorremos las categorias y su URL
# -------------------------------------
for nombre_categoria, url_categoria in categorias.items():

    print("Entrando a: ", nombre_categoria)

    # Abrimos la primera pagina de la categoria.
    next_page = url_categoria

    while next_page: # Mientras haya una nueva pagina entonces.

        # --- Request HTTP ---
        response = requests.get(next_page)
        response.raise_for_status() # Verificador de errores.

        # --- Parser Del HTMl ---
        soup     = BeautifulSoup(response.text, "html.parser")

        # --- Extraccion de los libros de la pagina ---
        books = soup.find_all("article", class_="product_pod")

        # --- Iteracion de cada libro ---
        for book in books:

            titulo = book.h3.a["title"]

            # --- Precio Limpio ---
            precio_raw    = book.find("p", class_="price_color").text
            precio_limpio = precio_raw.replace("Â", "").replace("£", "")
            precio        = float(precio_limpio)
            
            # --- Rating txt-float ---
            rating_text = book.find("p", class_="star-rating")["class"][1]
            rating = rating_map[rating_text]

            # --- Stock txt-bool ---
            stock_text  = book.find("p", class_="instock availability").text.strip()
            disponible = "In stock" in stock_text

            # --- Guardado De Datos Estructurado ---
            books_data.append({

                "titulo": titulo,
                "precio": precio,
                "rating": rating,
                "stock" : disponible,
                "categoria" : nombre_categoria
            })

        # --- Buscamos El boton De Next ---
        next_btn = soup.find("li", class_="next")

        # --- Extraemos El herf Relativo y reconstruimos la URL ---
        if next_btn:
            siguente_href = next_btn.a["href"]
            next_page = urljoin(next_page, siguente_href)
        
        else: # --- No se encontraron mas Next --- 
            next_page = None

# --- Verificaciones finales ---
print("Total libros scrapeados:", len(books_data))
type(books_data[0]["rating"])
# Out:
# Entrando a:  Travel
# Entrando a:  Mystery
# Entrando a:  Historical Fiction
# Entrando a:  Sequential Art
# Entrando a:  Classics
# Entrando a:  Philosophy
# Entrando a:  Romance
# Entrando a:  Womens Fiction
# Entrando a:  Fiction
# Entrando a:  Childrens
# Entrando a:  Religion
# Entrando a:  Nonfiction
# Entrando a:  Music
# Entrando a:  Default
# Entrando a:  Science Fiction
# Entrando a:  Sports and Games
# Entrando a:  Add a comment
# Entrando a:  Fantasy
# Entrando a:  New Adult
# Entrando a:  Young Adult
# Entrando a:  Science
# Entrando a:  Poetry
# Entrando a:  Paranormal
# Entrando a:  Art
# Entrando a:  Psychology
# Entrando a:  Autobiography
# Entrando a:  Parenting
# Entrando a:  Adult Fiction
# Entrando a:  Humor
# Entrando a:  Horror
# Entrando a:  History
# Entrando a:  Food and Drink
# Entrando a:  Christian Fiction
# Entrando a:  Business
# Entrando a:  Biography
# Entrando a:  Thriller
# Entrando a:  Contemporary
# Entrando a:  Spirituality
# ...

# %%
# ==================================
# BLOQUE 4: 
# ==================================

# --------------------------------------------
# TRANSFORMACION DE LA INFORMACION A DATAFRAME
# --------------------------------------------

# --- importacion de pandas ---
import pandas as pd

# --- Transformacion de la info a DataFrame ---
df = pd.DataFrame(books_data)

# --- Verificacion ---
df.info()

# --------------------------------------------
# FUNCION AUXILIAR (API Autores)
# --------------------------------------------
def obtener_autor_openlibrary(titulo):

    try:
        url_api = "https://openlibrary.org/search.json"
        params  = {"title": titulo}

        response = requests.get(url_api, params=params, timeout = 5)
        data = response.json()

        if data["docs"] and "author_name" in data["docs"][0]:
            return data["docs"][0]["author_name"][0]
        
        return None # -> Autor Desconocido.
    
    except:
        return None # -> Autor Desconocido.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   titulo     1000 non-null   object
#  1   precio     1000 non-null   float64
#  2   rating     1000 non-null   int64
#  3   stock      1000 non-null   bool
#  4   categoria  1000 non-null   object
# dtypes: bool(1), float64(1), int64(1), object(2)
# memory usage: 32.4+ KB

# %%
# ===========================================
# BLOQUE 5: ENRIQUECIMIENTO DEL SCRAPING
# ===========================================

# -------------------------------------------
# Obtener Autores con una API 
# -------------------------------------------
print("\n" + "="*60)
print("PROCESANDO AUTORES")
print("="*60)

# --- Librerias necesarias ---
import requests
from concurrent.futures import ThreadPoolExecutor # Sirve para ejecutar tareas en paralelo.
from concurrent.futures import as_completed       # Procesa los resultados a medida que terminan, sin un orden.


# --- Funcion para obtener Autores con la API ---
def obtener_autor_openlibrary(titulo):

    # --- URL de Open Library/API ---
    url_api = "https://openlibrary.org/search.json"
    #
    params  = {"title": titulo}

    try: 
        # --- Peticion Get a la API con espera de 5 segundos ---
        response = requests.get(url_api, params=params, timeout=5)
        response.raise_for_status() # Si el servidor devuelve un error salta a la exceptcion.
        data = response.json()      # Converitr a JSON.

        if data.get("docs"):                       # Verificar si hay resultado.
            for doc in data["docs"]:               # Recorrer resultados.
                if "author_name" in doc:           # Buscar autor.
                    return doc["author_name"]      # Tomar y retornar la lista de nombres de autores

        return [] # Retornar una lista vacia

    except:
        return [] # Captura posibles errores y retornar una lista vacia


# ----------------------------------------
# FUNCION PARA THREAD
# ----------------------------------------

def procesar_titulo(titulo):
    # --- Llama a la API ---
    autor = obtener_autor_openlibrary(titulo)
    return titulo, autor # Retornamos una tupla del titulo y una lista con el/los autores.


# ----------------------------------------
# EJECUCION CON THREADPOOL
# ----------------------------------------

# --- Diccionario de Autor:titulo/s ---
autores_dict = {} 

# --- Cantidad de Hilos activos ---
max_workers = 15  # entre 10 y 20 es ideal.

# --- Creacion de los hilos ---
with ThreadPoolExecutor(max_workers=max_workers) as executor:

    # --- Asignacion de Tareas a los hilos ---
    futures = [executor.submit(procesar_titulo, titulo) for titulo in df["titulo"]]
    
    # --- Tomar y enumerar los resultados ya listos ---
    for i, future in enumerate(as_completed(futures)): 
        
        # --- Obtener los resultados de cada futuro y desempaquetarlo ---
        titulo, autor = future.result()

        # --- Guardar resultados en un diccionarios ---
        autores_dict[titulo] = autor

        # --- Mostrar progreso ---
        if (i + 1) % 50 == 0: # Cada 50 resultados completados.
            print(f"{i+1}/{len(df)} procesados")


# ----------------------------------------
# ASIGNACION FINAL AL DATAFRAME
# ----------------------------------------

# --- Asociar y crear una columna con la lista de Autores a los titulos ---
df["autor"] = df["titulo"].map(autores_dict)

# ----------------------------------------
# RESUMEN FINAL DEL ENRIQUECIMIENTO
# ----------------------------------------

# --- LIBROS TOTALES ---
total_libros = len(df)

# --- LIBROS SIN AUTOR ---
libros_sin_autor = df["autor"].apply(lambda x: len(x) == 0).sum()

# --- AUTORES ENCONTRADOS ---
autores_encontrados = set()
for lista in df["autor"]:
    autores_encontrados.update(lista)

# --- Calculo de porcentaje ---
porcentaje = (len(autores_encontrados) / total_libros) * 100

# --- RESUMEN ---
print("\n" + "="*60)
print("RESUMEN DEL ENRIQUECIMIENTO")
print("="*60)

print(f"Total de libros procesados: {total_libros}")
print(f"Cantidad de autores únicos encontrados: {len(autores_encontrados)}")
print(f"Libros sin autor identificado: {libros_sin_autor}")
print(f"Porcentaje de enriquecimiento exitoso: {porcentaje:.2f}%")
# Out:
# ...
# PROCESANDO AUTORES
# ...
# 50/1000 procesados
# 100/1000 procesados
# 150/1000 procesados
# 200/1000 procesados
# 250/1000 procesados
# 300/1000 procesados
# 350/1000 procesados
# 400/1000 procesados
# 450/1000 procesados
# 500/1000 procesados
# 550/1000 procesados
# 600/1000 procesados
# 650/1000 procesados
# 700/1000 procesados
# 750/1000 procesados
# 800/1000 procesados
# 850/1000 procesados
# 900/1000 procesados
# 950/1000 procesados
# 1000/1000 procesados
#
# ...
# RESUMEN DEL ENRIQUECIMIENTO
# ...
# Total de libros procesados: 1000
# Cantidad de autores únicos encontrados: 452
# Libros sin autor identificado: 579
# Porcentaje de enriquecimiento exitoso: 45.20%

# %%
# ==================================
# BLOQUE 6: 
# ==================================

# -------------------------------------------
# CREACION DE BASE DE DATOS SQLITE
# -------------------------------------------
import sqlite3

# --- conectarse a la base de datos ---
conn = sqlite3.connect("books.db")

#
cursor = conn.cursor()

# ========================================= 
# CREACIÓN DE TABLAS (DDL)
# =========================================

cursor.execute("""
CREATE TABLE IF NOT EXISTS categorias (
    id_categoria INTEGER PRIMARY KEY AUTOINCREMENT,
    nombre TEXT UNIQUE
);
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS autores (
    id_autor INTEGER PRIMARY KEY AUTOINCREMENT,
    nombre TEXT UNIQUE
);
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS libros (
    id_libro INTEGER PRIMARY KEY AUTOINCREMENT,
    titulo TEXT UNIQUE,
    precio REAL,
    rating INTEGER,
    stock BOOLEAN,
    id_categoria INTEGER,
    FOREIGN KEY (id_categoria) REFERENCES categorias(id_categoria)
);
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS libro_autor (
    id_libro INTEGER,
    id_autor INTEGER,
    PRIMARY KEY (id_libro, id_autor),
    FOREIGN KEY (id_libro) REFERENCES libros(id_libro),
    FOREIGN KEY (id_autor) REFERENCES autores(id_autor)
);
""")

conn.commit()

# %% [markdown]
# ## DIAGRAMA ER - Modelo Relacional Librería
#
# ```mermaid
# erDiagram
#     CATEGORIAS {
#         int id_categoria PK
#         string nombre
#     }
#
#     LIBROS {
#         int id_libro PK
#         string titulo
#         float precio
#         int stock
#         int rating
#         int id_categoria FK
#     }
#
#     AUTORES {
#         int id_autor PK
#         string nombre
#     }
#
#     LIBRO_AUTOR {
#         int id_libro FK
#         int id_autor FK
#     }
#
#     CATEGORIAS ||--o{ LIBROS : contiene
#     LIBROS     ||--o{ LIBRO_AUTOR : tiene
#     AUTORES    ||--o{ LIBRO_AUTOR : escribe
# }
# ```

# %%
# ==================================
# BLOQUE 7: 
# ==================================

# --------------------------------------------
# INSERTAR CATEGORIAS
# --------------------------------------------

categorias_unicas = df["categoria"].dropna().unique()

for categoria in categorias_unicas:
    cursor.execute(
        "INSERT OR IGNORE INTO categorias (nombre) VALUES (?)",
        (categoria,)
    )

conn.commit()

# --------------------------------------------
# INSERTAR AUTORES


autores_unicos = set()

for lista in df["autor"].dropna(): # Recorremos cada lista de autores.
    autores_unicos.update(lista)   # Agregamos todos los autores al set.

for autor in autores_unicos:
    cursor.execute(
        "INSERT OR IGNORE INTO autores (nombre) VALUES (?)",
        (autor,)
    )

conn.commit()

# --------------------------------------------
# INSERCION DE LIBROS Y RELACIONES
# --------------------------------------------

for _, row in df.iterrows():

    # --- Obtener id_categoria ---
    cursor.execute(
        "SELECT id_categoria FROM categorias WHERE nombre = ?",
        (row["categoria"],)
    )
    # id_categoria = cursor.fetchone()[0].
    resultado_categoria = cursor.fetchone()

    if not resultado_categoria:
        continue # Si no existe la categoria, saltamos este libro.

    id_categoria = resultado_categoria[0]

    # ----------------------------------------
    # INSERTAR LIBRO (SIN DUPLICAR)
    # ----------------------------------------

    # --- INSERCION DE LIBROS Y RELACIONES ---
    cursor.execute("""
        INSERT OR IGNORE INTO libros (titulo, precio, rating, stock, id_categoria)
        VALUES (?, ?, ?, ?, ?)
""", (
    # --- Columnas ---
    row["titulo"],
    row["precio"],
    row["rating"],
    row["stock"],
    id_categoria
))
    # ---- Obtener SIEMPRE el id real del libro ----
    cursor.execute(
        "SELECT id_libro FROM libros WHERE titulo = ?",
        (row["titulo"],)
    )
    #
    resultado_libro = cursor.fetchone()
    #

    if not resultado_libro:
        continue
    
    #
    id_libro = resultado_libro[0]


    # ----------------------------------------
    # RELACION LIBRO - AUTOR
    # ----------------------------------------

    # === OBTENER id_autor ===
    if row["autor"]: #
        for autor in row["autor"]: # Recorremos cada autor.
            if autor is not None:  # Si autor tiene valor None.
                #
                cursor.execute(
                    "SELECT id_autor FROM autores WHERE nombre = ?",
                    (autor,)
                )
                #
                resultado_autor = cursor.fetchone()

                #
                if resultado_autor:
                    id_autor = resultado_autor[0]

                    # --- INSERTAR TABLA INTERMEDIA ---
                    cursor.execute("""
                        INSERT OR IGNORE INTO libro_autor (id_libro, id_autor)
                        VALUES (?, ?)
                        """, (id_libro, id_autor) )

conn.commit()

# %% [markdown]
# # BLOQUE 8  Consultas:

# %%
print("="*110)
print("CONSULTA 1   : Libros con rating > 3 y precio < £12")
print("OBJETIVO     : Detectar libros de buena calidad accesibles económicamente.")
print("IMPORTANCIA  : Permite identificar oportunidades de compra con alta relación calidad-precio.")
print("="*110)

query_1 = """
SELECT l.titulo, l.precio, l.rating, c.nombre AS categoria
FROM libros l
JOIN categorias c ON l.id_categoria = c.id_categoria
WHERE l.rating > 3
AND l.precio < 12
ORDER BY l.rating DESC, l.precio ASC;
"""

df_q1 = pd.read_sql_query(query_1, conn)
df_q1.head()
# Out:
# ...
# CONSULTA 1   : Libros con rating > 3 y precio < £10
# OBJETIVO     : Detectar libros de buena calidad accesibles económicamente.
# IMPORTANCIA  : Permite identificar oportunidades de compra con alta relación calidad-precio.
# ...
#                                               titulo  precio  rating  \
# 0                         An Abundance of Katherines   10.00       5
# 1                               Greek Mythic History   10.23       5
# 2  The Power Greens Cookbook: 140 Delicious Super...   11.05       5
# 3                                 Dear Mr. Knightley   11.21       5
# 4                                The Darkest Corners   11.33       5
#
#         categoria
# 0     Young Adult
# 1         Default
# 2  Food and Drink
# 3         Fiction
# 4     Young Adult

# %%
print("="*60)
print("CONSULTA 2: Top 5 autores con mejor promedio de rating")
print("Objetivo: Identificar autores más consistentes en calidad.")
print("Importancia: Útil para recomendaciones y análisis de reputación literaria.")
print("="*60)

query_2 = """
SELECT a.nombre,
        ROUND(AVG(l.rating), 2) AS promedio_rating,
        COUNT(*) AS cantidad_libros
FROM autores a
JOIN libro_autor la ON a.id_autor = la.id_autor
JOIN libros l ON la.id_libro = l.id_libro
GROUP BY a.id_autor
ORDER BY promedio_rating DESC
LIMIT 5;
"""

df_q2 = pd.read_sql_query(query_2, conn)
df_q2
# Out:
# ...
# CONSULTA 2: Top 5 autores con mejor promedio de rating
# Objetivo: Identificar autores más consistentes en calidad.
# Importancia: Útil para recomendaciones y análisis de reputación literaria.
# ...
#                  nombre  promedio_rating  cantidad_libros
# 0       Eric Klinenberg              5.0                1
# 1             Ayn Rand;              5.0                1
# 2         A. A. F. Azmy              5.0                1
# 3          Nicola Kraus              5.0                1
# 4  Sophie Bastide-Foltz              5.0                1

# %%
print("="*60)
print("CONSULTA 3: Precio promedio por categoría")
print("Objetivo: Analizar qué géneros son más costosos en promedio.")
print("Importancia: Permite estudiar posicionamiento de mercado por categoría.")
print("="*60)

query_3 = """
SELECT c.nombre,
        ROUND(AVG(l.precio), 2) AS precio_promedio,
        COUNT(*) AS cantidad_libros
FROM categorias c
JOIN libros l ON c.id_categoria = l.id_categoria
GROUP BY c.id_categoria
ORDER BY precio_promedio DESC;
"""

df_q3 = pd.read_sql_query(query_3, conn)
df_q3
# Out:
# ...
# CONSULTA 3: Precio promedio por categoría
# Objetivo: Analizar qué géneros son más costosos en promedio.
# Importancia: Permite estudiar posicionamiento de mercado por categoría.
# ...
#                 nombre  precio_promedio  cantidad_libros
# 0             Suspense            58.33                1
# 1               Novels            54.81                1
# 2             Politics            53.61                3
# 3               Health            51.45                4
# 4            New Adult            46.38                6
# 5            Christian            42.50                3
# 6     Sports and Games            41.17                5
# 7            Self Help            40.62                5
# 8               Travel            39.79               11
# 9              Fantasy            39.75               47
# 10                 Art            38.52                8
# 11           Parenting            37.35                1
# ...

# %%
print("="*60)
print("CONSULTA 4: Autores con libros de 1 estrella")
print("Objetivo: Detectar autores con baja recepción crítica.")
print("Importancia: Permite identificar patrones de bajo desempeño literario.")
print("="*60)

query_4 = """
SELECT a.nombre,
        COUNT(*) AS libros_con_una_estrella
FROM autores a
JOIN libro_autor la ON a.id_autor = la.id_autor
JOIN libros l ON la.id_libro = l.id_libro
WHERE l.rating = 1
GROUP BY a.id_autor
ORDER BY libros_con_una_estrella DESC;
"""

df_q4 = pd.read_sql_query(query_4, conn)
df_q4.head()
# Out:
# ...
# CONSULTA 4: Autores con libros de 1 estrella
# Objetivo: Detectar autores con baja recepción crítica.
# Importancia: Permite identificar patrones de bajo desempeño literario.
# ...
#                        nombre  libros_con_una_estrella
# 0                 Worth Books                        4
# 1                Harlan Coben                        2
# 2             Sophie Kinsella                        2
# 3  Lalla Ward Richard Dawkins                        1
# 4           Sharon L. Lechter                        1

# %%
print("="*60)
print("CONSULTA 5: Cantidad de libros por categoría")
print("Objetivo: Determinar qué géneros dominan el catálogo.")
print("Importancia: Permite analizar volumen editorial por categoría.")
print("="*60)

query_5 = """
SELECT c.nombre,
        COUNT(*) AS total_libros
FROM categorias c
JOIN libros l ON c.id_categoria = l.id_categoria
GROUP BY c.id_categoria
ORDER BY total_libros DESC;
"""

df_q5 = pd.read_sql_query(query_5, conn)
df_q5
# Out:
# ...
# CONSULTA 5: Cantidad de libros por categoría
# Objetivo: Determinar qué géneros dominan el catálogo.
# Importancia: Permite analizar volumen editorial por categoría.
# ...
#                 nombre  total_libros
# 0              Default           152
# 1           Nonfiction           110
# 2       Sequential Art            75
# 3        Add a comment            67
# 4              Fiction            65
# 5          Young Adult            54
# 6              Fantasy            47
# 7              Romance            35
# 8              Mystery            32
# 9       Food and Drink            30
# 10           Childrens            29
# 11  Historical Fiction            26
# 12              Poetry            19
# 13            Classics            19
# 14             History            18
# 15              Horror            17
# 16      Womens Fiction            17
# 17     Science Fiction            16
# 18             Science            14
# 19               Music            13
# ...

# %%
# ========================================================
# BLOQUE 9: OPTIMIZACIÓN Y COMPARACION CON Y SIN ÍNDICES
# ========================================================

# --- Importamos herramientas de tiempo ---
import time

# --- Cantidad de ejecuciones ---
ejecuciones = 100000

print("="*60)
print(f"DEMOSTRACIÓN DE INDEXACIÓN - {ejecuciones} EJECUCIONES")
print("="*60)

consulta_test = "SELECT * FROM libros WHERE id_categoria = 3"

# ------------------------------------------------
# 1️⃣ Eliminar índice si ya existe
# ------------------------------------------------
cursor.execute("DROP INDEX IF EXISTS idx_libros_categoria")
conn.commit()

print("\nMidiendo velocidad SIN índice...")

start = time.time()

for _ in range(ejecuciones):
    cursor.execute(consulta_test)
    cursor.fetchall()

tiempo_sin_indice = time.time() - start
print(f"Tiempo sin índice: {tiempo_sin_indice:.4f} segundos")


# ------------------------------------------------
# 2️⃣ Crear índice
# ------------------------------------------------
print("\nCreando índice sobre id_categoria...")

cursor.execute("""
CREATE INDEX IF NOT EXISTS idx_libros_categoria
ON libros(id_categoria);
""")
conn.commit()

print("Índice creado correctamente.")


# ------------------------------------------------
# 3️⃣ Medición CON índice
# ------------------------------------------------
print("\nMidiendo velocidad CON índice...")

start = time.time()

for _ in range(ejecuciones):
    cursor.execute(consulta_test)
    cursor.fetchall()

tiempo_con_indice = time.time() - start
print(f"Tiempo con índice: {tiempo_con_indice:.4f} segundos")


# ------------------------------------------------
# 4️⃣ Comparación
# ------------------------------------------------
print("\n" + "="*60)
print("COMPARACIÓN FINAL")
print("="*60)

print(f"Tiempo sin índice : {tiempo_sin_indice:.4f}")
print(f"Tiempo con índice : {tiempo_con_indice:.4f}")

if tiempo_con_indice < tiempo_sin_indice:
    mejora = ((tiempo_sin_indice - tiempo_con_indice) / tiempo_sin_indice) * 100
    print(f"\nMEJORA DE VELOCIDAD: {mejora:.2f}%")
else:
    print("\nNo hubo mejora significativa (dataset pequeño).")

print("\nConclusión: Los índices optimizan búsquedas filtradas en bases de datos grandes.")
# Out:
# ...
# DEMOSTRACIÓN DE INDEXACIÓN - 100000 EJECUCIONES
# ...
#
# Midiendo velocidad SIN índice...
# Tiempo sin índice: 15.1362 segundos
#
# Creando índice sobre id_categoria...
# Índice creado correctamente.
#
# Midiendo velocidad CON índice...
# Tiempo con índice: 8.4655 segundos
#
# ...
# COMPARACIÓN FINAL
# ...
# Tiempo sin índice : 15.1362
# Tiempo con índice : 8.4655
#
# MEJORA DE VELOCIDAD: 44.07%
#
# Conclusión: Los índices optimizan búsquedas filtradas en bases de datos grandes.

# %% [markdown]
# ## BLOQUE 10  GRAFICOS:

# %%
# ==========================================
# BONUS: Visualización gráfica
# ==========================================

import matplotlib.pyplot as plt

print("="*60)
print("GRÁFICO: Cantidad de libros por categoría")
print("Objetivo: Visualizar qué géneros dominan el catálogo.")
print("="*60)

# Ordenamos por cantidad (por si acaso)
df_grafico = df_q5.sort_values(by="total_libros", ascending=False).head(15)

plt.figure()
plt.bar(df_grafico["nombre"], df_grafico["total_libros"])

plt.xticks(rotation=90)
plt.xlabel("Categoría")
plt.ylabel("Cantidad de libros")
plt.title("Cantidad de libros por categoría")

plt.tight_layout()
plt.show()
# Out:
# ...
# GRÁFICO: Cantidad de libros por categoría
# Objetivo: Visualizar qué géneros dominan el catálogo.
# ...

# %%
# ==========================================
# PIE CHART - Top 5 categorías
# ==========================================

top5 = df["categoria"].value_counts().head(5)

plt.figure(figsize=(6,6))
plt.pie(top5, labels=top5.index, autopct="%1.1f%%")

plt.title("Top 5 categorías por cantidad de libros")

plt.tight_layout()
plt.show()
